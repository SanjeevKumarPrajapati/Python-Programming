# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
sns.scatterplot(x="cgpa",y="iq",data=df,hue="placement")
plt.show()

# %%
x=df.drop("placement",axis=1)

# %%
y=df["placement"]

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 85.0

# %%
lr.predict([[5.9,106.0	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
lr.coef_
# Out:
# array([[3.08692655, 0.00887102]])

# %%
lr.intercept_
# Out:
# array([-19.61194721])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.drop("Id",axis=1,inplace=True)

# %%
x=df.iloc[:,:-1]

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
sns.pairplot(data=df,hue="Species")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
le.fit(df["Species"])
# Out:
# LabelEncoder()

# %%
df["Species"]=le.transform(df["Species"])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df["Species"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
bx_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((120, 4), (120,))

# %%
lr1=LogisticRegression()

# %%
lr1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr1.score(x_test,y_test)
# Out:
# 1.0

# %%
lr1.predict([[5.1,3.5,1.4,0.2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# Species             0.782561     -0.419446       0.949043      0.956464
#
#                 Species
# SepalLengthCm  0.782561
# SepalWidthCm  -0.419446
# PetalLengthCm  0.949043
# PetalWidthCm   0.956464
# Species        1.000000

# %%
sns.scatterplot(x="Species",y="SepalLengthCm",data=df,color="r")
sns.scatterplot(x="Species",y="SepalWidthCm",data=df,color="g")
sns.scatterplot(x="Species",y="PetalLengthCm",data=df,color="b")
sns.scatterplot(x="Species",y="PetalWidthCm",data=df,color="orange")
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)

# %%
pf.fit(x)
# Out:
# PolynomialFeatures()

# %%
lr1
# Out:
# LogisticRegression()

# %%
y_pred=lr1.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
cf
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])

# %%
sns.heatmap(cf,annot=True)
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv("Social.csv")

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['EstimatedSalary'].plot(kind='hist', bins=20, title='EstimatedSalary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=df,hue="Purchased")
plt.show()

# %%
x=df.drop("Purchased",axis=1)

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=df["Purchased"]

# %%
from sklearn.preprocessing  import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(ss.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(max_depth=3)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
dt.score(x_test,y_test)*100
# Out:
# 91.25

# %%
dt.predict([[19,19000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
dt.predict([[35,20000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.tree import plot_tree

# %% [markdown]
# (decision_tree: Unknown, *, max_depth: Unknown | None = None, feature_names: Unknown | None = None, class_names: Unknown | None = None, label: str = "all", filled: bool = False, impurity: bool = True, node_ids: bool = False, proportion: bool = False, rounded: bool = False, precision: int = 3, ax: Unknown | None = None, fontsize: Unknown | None = None) -> list[Annotation | Unknown]

# %%
plt.figure(figsize=(50,50))
plot_tree(dt)
plt.savefig("tree.png")
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Social.csv")

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
df.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.155238   0.622454
# EstimatedSalary  0.155238         1.000000   0.362083
# Purchased        0.622454         0.362083   1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=df,hue="Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x=df.drop("Purchased",axis=1)

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=df["Purchased"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(ss.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# for i in range(1,5000):
#   x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
#   dt=DecisionTreeRegressor(max_depth=4)
#   dt.fit(x_train,y_train)
#   r=dt.score(x_test,y_test)
#   if r>0.90:
#     print(r,"      ",i)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=220)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt=DecisionTreeRegressor(max_depth=4)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
dt.score(x_test,y_test)
# Out:
# 0.9077057291914434

# %%
dt.score(x_train,y_train)
# Out:
# 0.7361530900715327

# %%
dt.predict([[35,20000	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1.])

# %%
plt.figure(figsize=(20,20))
plot_tree(dt)
plt.savefig("tree.png")
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
y_pred=dt.predict(x_test)

# %%
data=pd.DataFrame({"Actual Value":y_test,"Predicted Value":y_pred})

# %%
data.shape
# Out:
# (80, 2)

# %%
data.head(50)
# Out:
#      Actual Value  Predicted Value
# 273             1         0.714286
# 62              0         0.000000
# 86              0         0.000000
# 375             1         1.000000
# 189             0         0.000000
# 228             0         0.107692
# 72              0         0.000000
# 170             0         0.000000
# 79              0         0.000000
# 46              0         0.000000
# 7               1         0.950000
# 362             1         0.333333
# 333             0         0.107692
# 52              0         0.000000
# 56              0         0.000000
# 340             1         1.000000
# 302             1         0.950000
# 38              0         0.000000
# 151             0         0.107692
# 176             0         0.000000
# 237             0         0.107692
# 117             0         0.000000
# 68              0         0.000000
# 29              0         0.000000
# 251             0         0.107692
# 321             1         0.800000
# ...

# %%
plt.bar(data["Actual Value"],data["Predicted Value"],color=["green"])
plt.show()

# %%
sns.barplot(x="Actual Value",y="Predicted Value",data=data)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("Social.csv")

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=df["Purchased"]

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=df,hue="Purchased")
plt.show()

# %%
sc=StandardScaler()

# %%
sc.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(x_test,y_test)*100
# Out:
# 92.5

# %%
knn.score(x_train,y_train)*100
# Out:
# 92.5

# %%
for i in range(1,100):
  knn=KNeighborsClassifier(n_neighbors=i)
  knn.fit(x_train,y_train)
  test=knn.score(x_test,y_test)*100
  train=knn.score(x_train,y_train)*100
  print(test,"   ", train,"  ",abs(test-train),"   ",i)
# Out:
# 85.0     99.6875    14.6875     1
# 86.25     91.25    5.0     2
# 92.5     92.5    0.0     3
# 92.5     91.5625    0.9375     4
# 92.5     90.9375    1.5625     5
# 90.0     90.9375    0.9375     6
# 93.75     91.875    1.875     7
# 92.5     90.625    1.875     8
# 93.75     91.25    2.5     9
# 92.5     90.625    1.875     10
# 92.5     90.9375    1.5625     11
# 92.5     91.25    1.25     12
# 92.5     91.5625    0.9375     13
# 92.5     90.625    1.875     14
# 92.5     90.625    1.875     15
# 92.5     90.0    2.5     16
# 92.5     90.3125    2.1875     17
# 92.5     90.0    2.5     18
# 92.5     90.9375    1.5625     19
# 93.75     90.0    3.75     20
# 92.5     90.3125    2.1875     21
# 93.75     90.0    3.75     22
# 93.75     90.3125    3.4375     23
# 93.75     89.375    4.375     24
# 93.75     90.0    3.75     25
# 93.75     89.375    4.375     26
# 92.5     89.375    3.125     27
# 93.75     88.75    5.0     28
# 93.75     88.75    5.0     29
# ...

# %%
knn.predict([[-1.781797,-1.490046]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
y_pred=knn.predict(x_test)

# %%
data=pd.DataFrame({"Actual Value":y_test,"Predicted_Value":y_pred})

# %%
data
# Out:
#      Actual Value  Predicted_Value
# 209             0                1
# 280             1                1
# 33              0                0
# 210             1                1
# 93              0                0
# ..            ...              ...
# 246             0                0
# 227             1                1
# 369             1                1
# 176             0                0
# 289             1                0
#
# [80 rows x 2 columns]

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
df=pd.read_csv("placement-dataset.csv")

# %%
df.head()
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0
# 3   7.4  132          1
# 4   5.8  142          0

# %%
df.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
sns.scatterplot(x="cgpa",y="iq",data=df,hue="placement")
plt.show()

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#     cgpa   iq
# 0    6.8  123
# 1    5.9  106
# 2    5.3  121
# 3    7.4  132
# 4    5.8  142
# ..   ...  ...
# 95   4.3  200
# 96   4.4   42
# 97   6.7  182
# 98   6.3  103
# 99   6.2  113
#
# [100 rows x 2 columns]

# %%
y=df["placement"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.svm import SVC

# %%
#{'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'}

# %%
sv=SVC(kernel="linear")

# %%
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 90.0

# %%
sv.score(x_train,y_train)*100
# Out:
# 93.75

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
df=pd.read_csv("moon.csv")

# %%
sns.scatterplot(x="X1",y="X2",data=df,hue="label")
plt.show()

# %%
x=df.iloc[:,:-1]

# %%
y=df["label"]

# %%
x
# Out:
#            X1        X2
# 0   -0.926767 -0.111073
# 1   -0.917583  0.706006
# 2    0.437984  0.899093
# 3    0.089694  0.291446
# 4    0.110672 -0.070806
# ..        ...       ...
# 195 -0.540630  0.901834
# 196  0.032085  0.411465
# 197  0.691922  0.679103
# 198  0.017034  0.930984
# 199  0.212676 -0.026037
#
# [200 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
ss=SVC(kernel="rbf")

# %%
#{'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'}

# %%
ss.fit(x_train,y_train)
# Out:
# SVC()

# %%
ss.score(x_test,y_test)*100
# Out:
# 100.0

# %%
ss.score(x_train,y_train)*100
# Out:
# 100.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=ss)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
df=pd.read_csv("Housing.csv")

# %%
df.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus     price
# 0              no             yes        2      yes        furnished  13300000
# 1              no             yes        3       no        furnished  12250000
# 2              no              no        2      yes   semi-furnished  12250000
# 3              no             yes        3      yes        furnished  12215000
# 4              no             yes        2       no        furnished  11410000

# %%
x=df.iloc[:,:-1]

# %%
y=df["price"]

# %%
df.shape
# Out:
# (545, 13)

# %%
x.shape
# Out:
# (545, 12)

# %%
y.shape
# Out:
# (545,)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
lb.fit(x["mainroad"])
# Out:
# LabelEncoder()

# %%
x["mainroad"]=lb.transform(x["mainroad"])

# %%
for i in x.columns:
  if x[i].dtype=="O":
    lb.fit(x[i])
    x[i]=lb.transform(x[i])

# %%
sns.scatterplot(x="area",y="price",data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100
                                               )

# %%
from sklearn.svm import SVR

# %%
# {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'}

# %%
sr=SVR(kernel="linear")

# %%
sr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
sr.score(x_test,y_test)
# Out:
# 0.31650042658085265

# %%
sr.score(x_train,y_train)
# Out:
# 0.27053905950169765

# %%
sns.scatterplot(x="area",y="price",data=df)
plt.plot(x["area"],sr.predict(x),color="r")

# %%
import numpy as np
import pandas as pd
import matlotlib.pypl
