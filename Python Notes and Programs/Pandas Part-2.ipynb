# %% [markdown]
# # GroupBY

# %%
import pandas as pd

# %%
df=pd.read_csv("Students Performance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
a=df.groupby('gender')

# %%
for i in a:
    print(i)
# Out:
# ('female',      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
a.get_group("male")
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
a.get_group("female")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
c=df.groupby("lunch")

# %%
for i in c:
    print(i)
# Out:
# ('free/reduced',      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import numpy as np

# %% [markdown]
# # Aggregation

# %%
c.agg(np.mean)
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
c.agg(np.size)
# Out:
#               gender  race/ethnicity  parental level of education  \
# lunch
# free/reduced     355             355                          355
# standard         645             645                          645
#
#               test preparation course  math score  reading score  \
# lunch
# free/reduced                      355         355            355
# standard                          645         645            645
#
#               writing score
# lunch
# free/reduced            355
# standard                645

# %%
c.agg([np.mean,np.sum,np.std])
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\1855398718.py:1: FutureWarning: ['gender', 'race/ethnicity', 'parental level of education', 'test preparation course'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   c.agg([np.mean,np.sum,np.std])
#              math score                   reading score                    \
#                    mean    sum        std          mean    sum        std
# lunch
# free/reduced  58.921127  20917  15.159956     64.653521  22952  14.895339
# standard      70.034109  45172  13.653501     71.654264  46217  13.830602
#
#              writing score
#                       mean    sum        std
# lunch
# free/reduced     63.022535  22373  15.433823
# standard         70.823256  45681  14.339487

# %% [markdown]
# # Descriptive Statistics

# %%
# Sr.No.	Function	Description
# 1	count()	Number of non-null observations
# 2	sum()	Sum of values
# 3	mean()	Mean of Values
# 4	median()	Median of Values
# 5	mode()	Mode of values
# 6	std()	Standard Deviation of the Values
# 7	min()	Minimum Value
# 8	max()	Maximum Value
# 9	abs()	Absolute Value
# 10	prod()	Product of Values
# 11	cumsum()	Cumulative Sum
# 12	cumprod()	Cumulative Product

# %%
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
df.max()
# Out:
# gender                                     male
# race/ethnicity                          group E
# parental level of education    some high school
# lunch                                  standard
# test preparation course                    none
# math score                                  100
# reading score                               100
# writing score                               100
# dtype: object

# %% [markdown]
# # Iteration

# %%
# iteritems() − to iterate over the (key,value) pairs

# iterrows() − iterate over the rows as (index,series) pairs

# itertuples() − iterate over the rows as namedtuples

# %%
#iteritems() − to iterate over the (key,value) pairs
for i,j in df.iteritems():
    print(i,j)
# Out:
# gender 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object
# race/ethnicity 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object
# parental level of education 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object
# lunch 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
# ...

# %%
#iterrows() − iterate over the rows as (index,series) pairs
for i,j in df.iterrows():
    print(i,j)
# Out:
# 0 gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object
# 1 gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               69
# reading score                            90
# writing score                            88
# Name: 1, dtype: object
# 2 gender                                  female
# race/ethnicity                         group B
# parental level of education    master's degree
# ...

# %%
## itertuples() − iterate over the rows as namedtuples
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, gender='female', _2='group B', _3="bachelor's degree", lunch='standard', _5='none', _6=72, _7=72, _8=74)
# Pandas(Index=1, gender='female', _2='group C', _3='some college', lunch='standard', _5='completed', _6=69, _7=90, _8=88)
# Pandas(Index=2, gender='female', _2='group B', _3="master's degree", lunch='standard', _5='none', _6=90, _7=95, _8=93)
# Pandas(Index=3, gender='male', _2='group A', _3="associate's degree", lunch='free/reduced', _5='none', _6=47, _7=57, _8=44)
# Pandas(Index=4, gender='male', _2='group C', _3='some college', lunch='standard', _5='none', _6=76, _7=78, _8=75)
# Pandas(Index=5, gender='female', _2='group B', _3="associate's degree", lunch='standard', _5='none', _6=71, _7=83, _8=78)
# Pandas(Index=6, gender='female', _2='group B', _3='some college', lunch='standard', _5='completed', _6=88, _7=95, _8=92)
# Pandas(Index=7, gender='male', _2='group B', _3='some college', lunch='free/reduced', _5='none', _6=40, _7=43, _8=39)
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_index(ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values("math score")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values(by="reading score",kind="quicksort")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 76     male        group E            some high school      standard
# ..      ...            ...                         ...           ...
# 106  female        group D             master's degree      standard
# 594  female        group C           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values(by="reading score",kind="mergesort")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 76     male        group E            some high school      standard
# ..      ...            ...                         ...           ...
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Working with Text Data

# %%
# lower()

# Converts strings in the Series/Index to lower case.

# 2	
# upper()

# Converts strings in the Series/Index to upper case.

# 3	
# len()

# Computes String length().

# 4	
# strip()

# Helps strip whitespace(including newline) from each string in the Series/index from both the sides.

# 5	
# split(' ')

# Splits each string with the given pattern.

# 6	
# cat(sep=' ')

# Concatenates the series/index elements with given separator.

# 7	
# get_dummies()

# Returns the DataFrame with One-Hot Encoded values.

# 8	
# contains(pattern)

# Returns a Boolean value True for each element if the substring contains in the element, else False.

# 9	
# replace(a,b)

# Replaces the value a with the value b.

# 10	
# repeat(value)

# Repeats each element with specified number of times.

# 11	
# count(pattern)

# Returns count of appearance of pattern in each element.

# 12	
# startswith(pattern)

# Returns true if the element in the Series/Index starts with the pattern.

# 13	
# endswith(pattern)

# Returns true if the element in the Series/Index ends with the pattern.

# 14	
# find(pattern)

# Returns the first position of the first occurrence of the pattern.

# 15	
# findall(pattern)

# Returns a list of all occurrence of the pattern.

# 16	
# swapcase

# Swaps the case lower/upper.

# 17	
# islower()

# Checks whether all characters in each string in the Series/Index in lower case or not. Returns Boolean

# 18	
# isupper()

# Checks whether all characters in each string in the Series/Index in upper case or not. Returns Boolean.

# 19	
# isnumeric()

# Checks whether all characters in each string in the Series/Index are numeric. Returns Boolean.

# %%
df["gender"].str.lower()
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.upper()
# Out:
# 0      FEMALE
# 1      FEMALE
# 2      FEMALE
# 3        MALE
# 4        MALE
#         ...
# 995    FEMALE
# 996      MALE
# 997    FEMALE
# 998    FEMALE
# 999    FEMALE
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.len()
# Out:
# 0      6
# 1      6
# 2      6
# 3      4
# 4      4
#       ..
# 995    6
# 996    4
# 997    6
# 998    6
# 999    6
# Name: gender, Length: 1000, dtype: int64

# %%
#remove the character from both side left and right
df["gender"].str.strip("f")
# Out:
# 0      emale
# 1      emale
# 2      emale
# 3       male
# 4       male
#        ...
# 995    emale
# 996     male
# 997    emale
# 998    emale
# 999    emale
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.strip("e")
# Out:
# 0      femal
# 1      femal
# 2      femal
# 3        mal
# 4        mal
#        ...
# 995    femal
# 996      mal
# 997    femal
# 998    femal
# 999    femal
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.split('e')
# Out:
# 0      [f, mal, ]
# 1      [f, mal, ]
# 2      [f, mal, ]
# 3         [mal, ]
# 4         [mal, ]
#           ...
# 995    [f, mal, ]
# 996       [mal, ]
# 997    [f, mal, ]
# 998    [f, mal, ]
# 999    [f, mal, ]
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.cat()
# Out:
# '...'

# %%
df["gender"].str.cat(sep='_')
# Out:
# 'female_female_female_male_male_female_female_male_male_female_male_male_female_male_female_female_male_female_male_female_male_female_male_female_male_male_male_female_male_female_female_female_female_male_male_male_female_female_female_male_male_female_female_male_female_male_female_female_female_male_male_male_male_male_female_female_female_male_male_female_male_male_male_female_female_male_male_female_male_female_female_male_female_male_male_male_male_male_female_female_female_male_male_male_male_female_female_female_female_female_female_male_male_male_female_male_male_female_female_female_male_male_female_male_male_female_female_male_female_female_female_male_male_female_female_male_female_female_female_female_female_male_female_male_male_female_male_male_male_female_male_male_male_female_male_male_male_male_female_male_female_female_female_male_male_female_male_male_female_male_male_male_female_male_male_female_female_male_female_male_male_female_male_male_female_female_male_fe
# ...

# %%
df["gender"].str.cat(sep=",")
# Out:
# 'female,female,female,male,male,female,female,male,male,female,male,male,female,male,female,female,male,female,male,female,male,female,male,female,male,male,male,female,male,female,female,female,female,male,male,male,female,female,female,male,male,female,female,male,female,male,female,female,female,male,male,male,male,male,female,female,female,male,male,female,male,male,male,female,female,male,male,female,male,female,female,male,female,male,male,male,male,male,female,female,female,male,male,male,male,female,female,female,female,female,female,male,male,male,female,male,male,female,female,female,male,male,female,male,male,female,female,male,female,female,female,male,male,female,female,male,female,female,female,female,female,male,female,male,male,female,male,male,male,female,male,male,male,female,male,male,male,male,female,male,female,female,female,male,male,female,male,male,female,male,male,male,female,male,male,female,female,male,female,male,male,female,male,male,female,female,male,fe
# ...

# %%
# The get_dummies function is used to convert categorical variables into dummy or indicator variables. 
# A dummy or indicator variable can have a value of 0 or 1.
df["gender"].str.get_dummies()
# Out:
#      female  male
# 0         1     0
# 1         1     0
# 2         1     0
# 3         0     1
# 4         0     1
# ..      ...   ...
# 995       1     0
# 996       0     1
# 997       1     0
# 998       1     0
# 999       1     0
#
# [1000 rows x 2 columns]

# %%
df["gender"].str.contains('e')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.contains('z')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.replace("m","g")
# Out:
# 0      fegale
# 1      fegale
# 2      fegale
# 3        gale
# 4        gale
#         ...
# 995    fegale
# 996      gale
# 997    fegale
# 998    fegale
# 999    fegale
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.repeat(2)
# Out:
# 0      femalefemale
# 1      femalefemale
# 2      femalefemale
# 3          malemale
# 4          malemale
#            ...
# 995    femalefemale
# 996        malemale
# 997    femalefemale
# 998    femalefemale
# 999    femalefemale
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.count('e')
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 995    2
# 996    1
# 997    2
# 998    2
# 999    2
# Name: gender, Length: 1000, dtype: int64

# %%
df["gender"].str.startswith('f')
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.endswith('e')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.find('e')
# Out:
# 0      1
# 1      1
# 2      1
# 3      3
# 4      3
#       ..
# 995    1
# 996    3
# 997    1
# 998    1
# 999    1
# Name: gender, Length: 1000, dtype: int64

# %%
df["gender"].str.findall('e')
# Out:
# 0      [e, e]
# 1      [e, e]
# 2      [e, e]
# 3         [e]
# 4         [e]
#         ...
# 995    [e, e]
# 996       [e]
# 997    [e, e]
# 998    [e, e]
# 999    [e, e]
# Name: gender, Length: 1000, dtype: object

# %%
#it convert lower into upper or upper into lower
df["gender"].str.swapcase()
# Out:
# 0      FEMALE
# 1      FEMALE
# 2      FEMALE
# 3        MALE
# 4        MALE
#         ...
# 995    FEMALE
# 996      MALE
# 997    FEMALE
# 998    FEMALE
# 999    FEMALE
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.islower()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.isupper()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %% [markdown]
# # Statistical Functions

# %%
# ρ (X,Y) = cov (X,Y) / σX.σY. Here cov is the covariance. 
# σX is the standard deviation of X and σY is the standard deviation of Y

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
#cov(x,y)=sum((x-mean(x))*(y-mean(y))/N-1

# cov_{x,y}	=	covariance between variable x and y
# x_{i}	=	data value of x
# y_{i}	=	data value of y
# \bar{x}	=	mean of x
# \bar{y}	=	mean of y
# N	=	number of data values

# %%
df.cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
#Data Ranking produces ranking for each element in the array of elements. In case of ties, assigns the mean rank.
df.rank()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     259.5           184.5                        281.5  678.0
# 1     259.5           439.0                        708.5  678.0
# 2     259.5           184.5                        566.0  678.0
# 3     759.5            45.0                        111.5  178.0
# 4     759.5           439.0                        708.5  678.0
# ..      ...             ...                          ...    ...
# 995   259.5           930.5                        566.0  678.0
# 996   759.5           439.0                        438.5  178.0
# 997   259.5           439.0                        438.5  178.0
# 998   259.5           729.5                        708.5  678.0
# 999   259.5           729.5                        708.5  178.0
#
#      test preparation course  math score  reading score  writing score
# 0                      679.5       644.5          550.5          633.0
# ...

# %%
df.mean()
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df.max()
# Out:
# gender                                     male
# race/ethnicity                          group E
# parental level of education    some high school
# lunch                                  standard
# test preparation course                    none
# math score                                  100
# reading score                               100
# writing score                               100
# dtype: object

# %%
df.min()
# Out:
# gender                                     female
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                      0
# reading score                                  17
# writing score                                  10
# dtype: object

# %% [markdown]
# # Missing Data

# %%
#isnull()
#notnull

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True            True                         True   True
# 3      True            True                         True   True
# 4      True            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
df["reading score"].sum()
# Out:
# 69169

# %%
df.fillna(0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#insertion method
# pad/fill

# Fill methods Forward

# 2	
# bfill/backfill

# Fill methods Backward

# %%
df.fillna(method="pad")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.fillna(method="backfill")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#drop missing values

# %%
df.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.dropna(axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Merging

# %%
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
# left_index=False, right_index=False, sort=True)

# %%
# left − A DataFrame object.

# right − Another DataFrame object.

# on − Columns (names) to join on. Must be found in both the left and right DataFrame objects.

# left_on − Columns from the left DataFrame to use as keys. Can either be column names or arrays with 
# length equal to the length of the DataFrame.

# right_on − Columns from the right DataFrame to use as keys. Can either be column names or arrays with 
# length equal to the length of the DataFrame.

# left_index − If True, use the index (row labels) from the left DataFrame as its join key(s). In case of 
# a DataFrame with a MultiIndex (hierarchical), the number of levels must match the number of join keys from the right DataFrame.

# right_index − Same usage as left_index for the right DataFrame.

# how − One of 'left', 'right', 'outer', 'inner'. Defaults to inner. Each method has been described below.

# sort − Sort the result DataFrame by the join keys in lexicographical order. Defaults to True, setting to False 
# will improve the performance substantially in many cases.

# %%
import pandas as pd
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
left
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %%
right
# Out:
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %%
pd.merge(left,right,on='id')
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %%
pd.merge(left,right,on=['id','subject_id'])
# Out:
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %%
# Merge Method	SQL Equivalent	Description
# left	LEFT OUTER JOIN	Use keys from left object
# right	RIGHT OUTER JOIN	Use keys from right object
# outer	FULL OUTER JOIN	Use union of keys
# inner	INNER JOIN	Use intersection of keys

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
left
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %%
right
# Out:
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %% [markdown]
# # Left Join

# %%
pd.merge(left, right, on='subject_id', how='left')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     1    Alex       sub1   NaN    NaN
# 1     2     Amy       sub2   1.0  Billy
# 2     3   Allen       sub4   2.0  Brian
# 3     4   Alice       sub6   4.0  Bryce
# 4     5  Ayoung       sub5   5.0  Betty

# %% [markdown]
# # Right Join

# %%
pd.merge(left, right, on='subject_id', how='right')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   2.0     Amy       sub2     1  Billy
# 1   3.0   Allen       sub4     2  Brian
# 2   NaN     NaN       sub3     3   Bran
# 3   4.0   Alice       sub6     4  Bryce
# 4   5.0  Ayoung       sub5     5  Betty

# %% [markdown]
# # Full Outer Join

# %%
pd.merge(left, right, how='outer', on='subject_id')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   1.0    Alex       sub1   NaN    NaN
# 1   2.0     Amy       sub2   1.0  Billy
# 2   3.0   Allen       sub4   2.0  Brian
# 3   4.0   Alice       sub6   4.0  Bryce
# 4   5.0  Ayoung       sub5   5.0  Betty
# 5   NaN     NaN       sub3   3.0   Bran

# %% [markdown]
# # Inner Join

# %%
pd.merge(left, right, on='subject_id', how='inner')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     2     Amy       sub2     1  Billy
# 1     3   Allen       sub4     2  Brian
# 2     4   Alice       sub6     4  Bryce
# 3     5  Ayoung       sub5     5  Betty

# %% [markdown]
# # Concatenation

# %%
#syntax

# %%
# pd.concat(objs,axis=0,join='outer',join_axes=None,
# ignore_index=False)

# %%
# objs − This is a sequence or mapping of Series, DataFrame, or Panel objects.

# axis − {0, 1, ...}, default 0. This is the axis to concatenate along.

# join − {‘inner’, ‘outer’}, default ‘outer’. How to handle indexes on other axis(es). 
# Outer for union and inner for intersection.

# ignore_index − boolean, default False. If True, do not use the index values on the concatenation axis. 
# The resulting axis will be labeled 0, ..., n - 1.

# join_axes − This is the list of Index objects. Specific indexes to use for the other (n-1) axes instead of 
# performing inner/outer set logic.

# %%
one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,5])

two = pd.DataFrame({
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
pd.concat([one,two])
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
pd.concat([one,two],keys=['x','y'])
# Out:
#        Name subject_id  Marks_scored
# x 1    Alex       sub1            98
#   2     Amy       sub2            90
#   3   Allen       sub4            87
#   4   Alice       sub6            69
#   5  Ayoung       sub5            78
# y 1   Billy       sub2            89
#   2   Brian       sub4            80
#   3    Bran       sub3            79
#   4   Bryce       sub6            97
#   5   Betty       sub5            88

# %%
pd.concat([one,two],keys=['x','y'],ignore_index=True)
# Out:
#      Name subject_id  Marks_scored
# 0    Alex       sub1            98
# 1     Amy       sub2            90
# 2   Allen       sub4            87
# 3   Alice       sub6            69
# 4  Ayoung       sub5            78
# 5   Billy       sub2            89
# 6   Brian       sub4            80
# 7    Bran       sub3            79
# 8   Bryce       sub6            97
# 9   Betty       sub5            88

# %%
pd.concat([one,two],axis=1)
# Out:
#      Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1    Alex       sub1            98  Billy       sub2            89
# 2     Amy       sub2            90  Brian       sub4            80
# 3   Allen       sub4            87   Bran       sub3            79
# 4   Alice       sub6            69  Bryce       sub6            97
# 5  Ayoung       sub5            78  Betty       sub5            88

# %%
one.append(two)
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\492145729.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   one.append(two)
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
one.append([two,one,two])
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\687072293.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   one.append([two,one,two])
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# ...

# %% [markdown]
# # Time Series

# %%
pd.datetime.now()
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\627754903.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime.now()
# datetime.datetime(2023, 3, 16, 21, 47, 25, 80072)

# %% [markdown]
# # Create a TimeStamp

# %%
pd.Timestamp('2023-03-17')
# Out:
# Timestamp('2023-03-17 00:00:00')

# %%
# It is also possible to convert integer or float epoch times. The default unit for these is nanoseconds
# (since these are how Timestamps are stored). However, often epochs are stored in another 
# unit which can be specified

# %%
pd.Timestamp(1587687255,unit='s')
# Out:
# Timestamp('2020-04-24 00:14:15')

# %% [markdown]
# # Create a Range of Time

# %%
pd.date_range("11:00", "13:30", freq="30min").time
# Out:
# array([datetime.time(11, 0), datetime.time(11, 30), datetime.time(12, 0),
#        datetime.time(12, 30), datetime.time(13, 0), datetime.time(13, 30)],
#       dtype=object)

# %% [markdown]
# # Change the Frequency of Time

# %%
pd.date_range("11:00", "13:30", freq="H").time
# Out:
# array([datetime.time(11, 0), datetime.time(12, 0), datetime.time(13, 0)],
#       dtype=object)

# %% [markdown]
# # Converting to Timestamps

# %%
pd.to_datetime(pd.Series(['Jul 31, 2009','2010-01-10', None]))
# Out:
# 0   2009-07-31
# 1   2010-01-10
# 2          NaT
# dtype: datetime64[ns]

# %%
pd.to_datetime(['2005/11/23', '2010.12.31', None])
# Out:
# DatetimeIndex(['2005-11-23', '2010-12-31', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # Date Functionality

# %%
pd.date_range('1/1/2011', periods=5)
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Change the Date Frequency

# %%
pd.date_range('1/1/2011', periods=5,freq='M')
# Out:
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
start = pd.datetime(2011, 1, 1)
end = pd.datetime(2011, 1, 5)

pd.date_range(start, end)
# Out:
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\317602078.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   start = pd.datetime(2011, 1, 1)
# C:\Users\Sanjeev Kumar\AppData\Local\Temp\ipykernel_10396\317602078.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end = pd.datetime(2011, 1, 5)
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Timedelta

# %%
pd.Timedelta('2 days 2 hours 15 minutes 30 seconds')
# Out:
# Timedelta('2 days 02:15:30')

# %%
pd.Timedelta(6,unit='h')
# Out:
# Timedelta('0 days 06:00:00')

# %%
pd.Timedelta(days=2)
# Out:
# Timedelta('2 days 00:00:00')

# %%
s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))
td = pd.Series([ pd.Timedelta(days=i) for i in range(3) ])
df = pd.DataFrame(dict(A = s, B = td))

# %%
s
# Out:
# 0   2012-01-01
# 1   2012-01-02
# 2   2012-01-03
# dtype: datetime64[ns]

# %%
td
# Out:
# 0   0 days
# 1   1 days
# 2   2 days
# dtype: timedelta64[ns]

# %%
df
# Out:
#            A      B
# 0 2012-01-01 0 days
# 1 2012-01-02 1 days
# 2 2012-01-03 2 days

# %% [markdown]
# # Addition Operations

# %%
s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))
td = pd.Series([ pd.Timedelta(days=i) for i in range(3) ])
df = pd.DataFrame(dict(A = s, B = td))
df['C']=df['A']+df['B']

# %%
df
# Out:
#            A      B          C
# 0 2012-01-01 0 days 2012-01-01
# 1 2012-01-02 1 days 2012-01-03
# 2 2012-01-03 2 days 2012-01-05

# %%
s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))
td = pd.Series([ pd.Timedelta(days=i) for i in range(3) ])
df = pd.DataFrame(dict(A = s, B = td))
df['C']=df['A']+df['B']
df['D']=df['C']+df['B']

# %%
df
# Out:
#            A      B          C          D
# 0 2012-01-01 0 days 2012-01-01 2012-01-01
# 1 2012-01-02 1 days 2012-01-03 2012-01-04
# 2 2012-01-03 2 days 2012-01-05 2012-01-07

# %% [markdown]
# # Visualization

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b',color="r")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='x'>], dtype=object)
